# %%
import pandas as pd

# %%
df_溫熱型開飲機 = pd.read_excel('./fwdsampledata\\溫熱型開飲機節能標章產品規格(含108-110年產銷量).xlsx')
df_110 = pd.read_excel('./fwdsampledata\\已登錄產品之細項與核准項目 (溫熱型開飲機_ALL)-110.xlsx')
df_110_1 = pd.read_excel('./fwdsampledata\\已登錄產品之細項與核准項目 (溫熱型開飲機_ALL)-110_1.xlsx')
df_111 = pd.read_excel('./fwdsampledata\\已登錄產品之細項與核准項目 (溫熱型開飲機_ALL)-111.xlsx')

# %%
pd.merge(df_111['產品型號'],df_溫熱型開飲機['型號'], left_on='產品型號',right_on='型號', how='inner')
# Out:
#           產品型號          型號
# 0      JD-3703     JD-3703
# 1      JD-3718     JD-3718
# 2      TE-186C     TE-186C
# 3     TE-1132C    TE-1132C
# 4      TE-333C     TE-333C
# 5     JWD825MB    JWD825MB
# 6      TE-1161     TE-1161
# 7     YL0836CB    YL0836CB
# 8     YS-825DW    YS-825DW
# 9     YL0838CB    YL0838CB
# 10     JD-3688     JD-3688
# 11     JD-5460     JD-5460
# 12      PL-801      PL-801
# 13  YS-8305DWG  YS-8305DWG
# 14   YS-8626DW   YS-8626DW
# 15     TE-1168     TE-1168
# 16  YS-8300DWB  YS-8300DWB
# 17    TE-1131S    TE-1131S
# 18    YS-825DW    YS-825DW
# 19     JD-3225     JD-3225
# 20     JD-5335     JD-5335
# 21     JD-3600     JD-3600
# 22     JD-3623     JD-3623
# 23     JD-3628     JD-3628
# 24     JD-3223     JD-3223
# 25     JD-3699     JD-3699
# 26     JD-3221     JD-3221
# 27     JD-3663     JD-3663
# 28   YS-9387DW   YS-9387DW
# 29   SWD-8075S   SWD-8075S
# 30    TE-1153A    TE-1153A
# 31    YS-826DW    YS-826DW
# 32   YS-9387DW   YS-9387DW
# ...

# %%
for file in [
            # './fwdsampledata\\冰溫熱型開飲機節能標章產品規格(含108-110年產銷量).xlsx',
            # './fwdsampledata\\已登錄產品之細項與核准項目 (冰溫熱型開飲機_ALL)-109.xlsx',
            # './fwdsampledata\\已登錄產品之細項與核准項目 (冰溫熱型開飲機_ALL)-110.xlsx',
            # './fwdsampledata\\已登錄產品之細項與核准項目 (冰溫熱型開飲機_ALL)-111.xlsx',
            './fwdsampledata\\已登錄產品之細項與核准項目 (溫熱型開飲機_ALL)-110.xlsx',
            './fwdsampledata\\已登錄產品之細項與核准項目 (溫熱型開飲機_ALL)-110_1.xlsx',
            './fwdsampledata\\已登錄產品之細項與核准項目 (溫熱型開飲機_ALL)-111.xlsx',
            './fwdsampledata\\溫熱型開飲機節能標章產品規格(含108-110年產銷量).xlsx'
            ]:
    
    # print(file)
    # df = pd.read_excel(file)
    # if '型號' in df:
    #     print(df['型號'])
    # elif '產品型號' in df:
    #     print(df['產品型號'])
    # if '申請序號' in df:
    #     print(df['申請序號'])
    # elif '申請案號' in df:
    #     print(df['申請案號'])
# Out:
# ./fwdsampledata\冰溫熱型開飲機節能標章產品規格(含108-110年產銷量).xlsx
# 0       JD-8805
# 1    YS-9980DWI
# Name: 型號, dtype: object
# ./fwdsampledata\已登錄產品之細項與核准項目 (冰溫熱型開飲機_ALL)-109.xlsx
# 0         JD-6723
# 1         JD-6718
# 2         JD-6712
# 3         JD-6721
# 4         JD-6607
# 5         JD-6726
# 6         JD-6725
# 7         JD-6211
# 8         JD-6206
# 9         JD-6207
# 10        JD-6726
# 11        JD-6211
# 12        JD-6712
# 13        JD-6718
# 14        JD-6206
# 15        JD-6723
# 16        JD-6607
# 17        JD-6621
# 18        JD-6721
# 19     TCY-563701
# 20     YS-9980DWI
# 21        JD-8508
# 22        JD-8507
# 23        JD-8305
# 24        AP-9061
# 25        AP-9068
# 26        JD-6207
# 27        JD-6621
# 28        JD-6716
# 29        JD-8302
# 30        JD-8302
# 31        JD-6725
# 32        JD-6716
# 33        JD-6719
# 34        JD-6209
# 35        JD-6727
# 36        JD-6728
# 37        JD-6609
# 38    YS-9980DWIE
# 39    YS-9990DWIE
# 40        TE-153A
# ...

# %%
df.columns
# Out:
# Index(['申請序號', '標章公司', '合約號', '類別名稱', '型號', '產地', '測試單位', '起約日期', '到約日期',
#        '廠牌名稱', '商驗證編號', '商驗證有效日期', 'CCCCode', '108產量', '108銷售量', '109產量',
#        '109銷售量', '110產量', '110銷售量', '測試報告編號', '能效型號', '是否為測試型號',
#        '系列型號參照之測試報告型號<br>', '寬(mm)', '高(mm)', '深(mm)', '熱水總功率(W)', '保溫功率(W)',
#        '包裝飲用水專用機', '生水容量(L)', '實測熱水貯水桶容量(L)', '標示熱水貯水桶容量V1(L)',
#        '熱水系統24小時平均水溫Th(℃)', '溫水貯水桶容量(L)', '溫水溫度(℃)', '實測冰水貯水桶容量(L)',
#        '標示冰水貯水桶容量V1(L)', '冰水系統24小時平均水溫Tc(℃)', '週圍溫度Tamb(℃)',
#        '能源因素值EFtest (L/(kWh/day))', '能源因素值EFbase(L/(kWh/day))',
#        '每24小時備用損失E24(kWh/24h)實測值', '每24小時備用損失E24(kWh/24h)標示值', '熱水膽溫度校正係數K1',
#        '冰水膽溫度校正係數K2', '冰溫熱型開飲機節能標章能源耗用基準E(kWh/24h)'],
#       dtype='object')

# %%
df_111.columns
# Out:
# Index(['產品類別', '申請案號', '登錄編號', '登錄年度', '登錄身分', '受委託登錄機構', '標示義務公司', '生產廠場名稱',
#        '產品類別.1', '2021產量', '2021銷售量', '產品型號', '銘版產地', '產品能源效率', '產品效率分級',
#        '最低能源效率基準', '是否符合最低能源效率基準', '廠牌名稱', '登錄通過日期', '安規試驗單位', '系列型號參照之測試報告型號',
#        '額定最大消耗功率(W)', '額定熱水系統消耗功率(W)', '額定保溫加熱器消耗功率(W)', '熱水系統貯水桶容量標示值(L)',
#        '熱水系統貯水桶容量實測值(L)', '溫水貯水桶容量標示值(L)', '溫水貯水桶容量實測值(L)', '熱水系統24小時平均水溫(℃)',
#        '周圍溫度(℃)', '每24小時備用損失E24(kWh/24小時)標示值', '每24小時備用損失E24(kWh/24小時)實測值',
#        '每24小時標準化備用損失Est,24 (kWh/24小時)標示值', '每24小時標準化備用損失Est,24 (kWh/24小時)實測值',
#        '每年保溫耗電量', '最低容許耗能基準測試標準及方法', '進口_國產', '失效日期', '失效原因', '檢測報告編號',
#        '驗證登錄證書號碼', '申請時間', '收件日期', 'BSMI證書列示國別', 'BSMI證書列示廠址'],
#       dtype='object')

# %%
df_111['2021產量'].plot()
# Out:
# <Axes: >

# %%
import pandas as pd

count = 1
df_list = []
for path in [
        #     './fwdsampledata\\冰溫熱型開飲機節能標章產品規格(含108-110年產銷量).xlsx',
            './fwdsampledata\\已登錄產品之細項與核准項目 (冰溫熱型開飲機_ALL)-109.xlsx',
            './fwdsampledata\\已登錄產品之細項與核准項目 (冰溫熱型開飲機_ALL)-110.xlsx',
            './fwdsampledata\\已登錄產品之細項與核准項目 (冰溫熱型開飲機_ALL)-111.xlsx',
            ]:
    df = pd.read_excel(path)
    df_list.append(df)
df_whole = pd.concat(df_list)

# %%
df_whole.to_excel('./fwdsampledata\\已登錄產品之細項與核准項目_whole.xlsx', index=False)

# %%
count = 1
df_list = []
for path in [
            # './fwdsampledata\\冰溫熱型開飲機節能標章產品規格(含108-110年產銷量).xlsx',
            './fwdsampledata\\已登錄產品之細項與核准項目 (冰溫熱型開飲機_ALL)-109.xlsx',
            './fwdsampledata\\已登錄產品之細項與核准項目 (冰溫熱型開飲機_ALL)-110.xlsx',
            './fwdsampledata\\已登錄產品之細項與核准項目 (冰溫熱型開飲機_ALL)-111.xlsx',
            ]:
    df = pd.read_excel(path)
    df_list.append(df)
pd.concat(df_list).to_excel('./fwdsampledata\\已登錄產品之細項與核准項目_冰溫熱型開飲機_ALL_whole.xlsx', index=False)

# %%
from dataclasses import dataclass

# %%
@dataclass
class Stock:
    ticker: str  # Stock ticker symbol
    exchange: str  # Stock exchange where the stock is traded
    price: float = 0  # Current price of the stock
    currency: str = "USD"  # Currency in which the stock price is denoted
    usd_price: float = 0  # Price of the stock converted to USD

    # Post-initialization method to fetch price information for the stock
    def __post_init__(self):
        # Call the function to retrieve price information
        price_info = get_price_information(self.ticker, self.exchange)

        # Update stock attributes based on the retrieved price information
        if price_info["ticker"] == self.ticker:
            self.price = price_info["price"]
            self.currency = price_info["currency"]
            self.usd_price = price_info["usd_price"]
